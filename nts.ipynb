# %% [markdown]
# <a href="https://colab.research.google.com/github/manbarrvil/AI_USE_labs/blob/main/nts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MODELADO NTS GENERADORES SINCRONOS**

# %%
# %pip install --upgrade pydae --quiet
# %pip install --upgrade pydae-bps --quiet
# %pip install --upgrade casadi --quiet
# %pip install hjson

# %%
import hjson

# Abrimos el archivo HJSON
with open('nts_base.hjson', 'r', encoding='utf-8') as archivo:
    # hjson.load() se encarga de procesar el formato flexible
    datos = hjson.load(archivo)

# Ahora 'datos' es un diccionario estándar de Python
print(datos)
# Out:
# OrderedDict({'system': OrderedDict({'name': 'nts', 'S_base': 1000000000}), 'agc': OrderedDict({'gen': '4', 'K_p_agc': 0, 'K_i_agc': 0.001}), 'buses': [OrderedDict({'name': '1', 'P_W': 0, 'Q_var': 0, 'U_kV': 19}), OrderedDict({'name': '2', 'P_W': 0, 'Q_var': 0, 'U_kV': 230}), OrderedDict({'name': '3', 'P_W': 0, 'Q_var': 0, 'U_kV': 230}), OrderedDict({'name': '4', 'P_W': 0, 'Q_var': 0, 'U_kV': 19}), OrderedDict({'name': '5', 'P_W': 0, 'Q_var': 0, 'U_kV': 19})], 'lines': [OrderedDict({'bus_j': '1', 'bus_k': '2', 'X_pu': 0.15, 'R_pu': 0, 'S_mva': 1500}), OrderedDict({'bus_j': '2', 'bus_k': '3', 'X_pu': 0.01, 'R_pu': 0, 'Bs_pu': 0, 'S_mva': 100}), OrderedDict({'bus_j': '3', 'bus_k': '4', 'X_pu': 0.15, 'R_pu': 0, 'S_mva': 5000}), OrderedDict({'bus_j': '5', 'bus_k': '2', 'X_pu': 0.01, 'R_pu': 0, 'S_mva': 1000})], 'loads': [OrderedDict({'bus': '2', 'type': 'zip', 'p_mw': 1250, 'q_mvar': 0, 'K_zp': 0, 'K_zq': 1, 'K_ip': 1, 'K_iq': 0}), OrderedDict({'bus': '3', 'type': 'zip', 'p_mw': 4000, 'q_
# ...
